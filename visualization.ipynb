# %%
import astropy
from astropy.io import fits
import numpy as np
import matplotlib.pyplot as plt

# %%
fit  = fits.open(r"C:\Users\opera\OneDrive\Documentos\GitHub\EXXAtest\data\planet0_00226_1250.fits")  #load the fits file

# %%
fit.info() # info of the file
# Out:
# Filename: C:\Users\opera\OneDrive\Documentos\GitHub\EXXAtest\data\planet0_00226_1250.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU      27   (600, 600, 1, 1, 4)   float32
#   1                1 ImageHDU        10   (4, 1, 1, 2)   float32
#   2                1 ImageHDU         9   (4, 1, 1)   float32
#   3                1 ImageHDU         8   (3, 4)   float32

# %%
image_data= fit[0].data # extract the index 0 data

# %%
image_data.shape #dimention of the data (4,1,600,600)
# Out:
# (4, 1, 1, 600, 600)

# %%
image_data = image_data[0,:,:,:,:]

# %%
image_data.shape
# Out:
# (1, 1, 600, 600)

# %%
image_data = np.squeeze(image_data)  
image_data.shape # (600,600)
# Out:
# (600, 600)

# %%
plt.imshow(image_data, cmap='gray') # show the image
plt.colorbar() # add color bar
